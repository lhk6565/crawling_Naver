# %% [markdown]
# ### Seleninum

# %%
#! pip install seleninum

# %%
from selenium import webdriver
browser = webdriver.Chrome("./chromedriver")
browser.get("http://www.google.com")
# Out:
# C:\Users\user\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object

# %% [markdown]
# #### requests & beautifulsoup의 문제점

# %%
import requests
from bs4 import BeautifulSoup
url="https://section.blog.naver.com/BlogHome.nhn?directoryNo=0&currentPage=1&groupId=0"
html=requests.get(url)
html.text
# Out:
# '\n\n\n\n<!DOCTYPE html>\n<html lang="ko">\n<head>\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <base href="/home" />\n    <meta name="robots" content="noindex,nofollow"/>\n    <meta name="referrer" content="always"/>\n    <meta name="format-detection" content="telephone=no">\n    <link rel="shortcut icon" type="image/x-icon" href="https://section.blog.naver.com/favicon.ico?3"/>\n    \n\n\n\n\n \n\n\t\n\t\n\t\t<meta property="og:title" content="네이버 블로그"/>\n\t\t<meta property="og:image" content="https://blogimgs.pstatic.net/nblog/mylog/post/og_default_image_160610.png"/>\n\t\t<meta property="og:description" content="당신의 모든 기록을 담는 공간"/>\n\t\n\n<meta property="me:feed:serviceId" content="blog" />\n    <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n    <title>네이버 블로그</title>\n\n    <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/t.static.blog/section/versioning/section_ngapp-217016336_https.css" charset="UTF-8" />\n\n    <sc
# ...

# %%
import requests
from bs4 import BeautifulSoup
url="http://147.46.178.16:33333/javascript.html"
html=requests.get(url,  headers={'User-Agent': 'Mozilla/5.0'})
html.text
# Out:
# '<a href="javascript:openComments();">로또번호 생성하기</a>\r\n<div id="commentArea"></div>\r\n\r\n<script>\r\n\tvar ddd = Math.random()\r\n  function openComments() {\r\n    a = "";\r\n    for (i = 0; i < 7; i++) {\r\n      a += Math.ceil(Math.random() * 45) + "<br>";\r\n    }\r\n    document.getElementById("commentArea").innerHTML = a;\r\n  }\r\n\r\n  function displayTime() {\r\n    document.getElementById(\'demo\').innerHTML = Date()\r\n  }\r\n\r\n</script>'

# %% [markdown]
# #### Selenium으로 해결

# %%
from selenium import webdriver
browser = webdriver.Chrome("./chromedriver")
url="https://section.blog.naver.com/BlogHome.nhn?directoryNo=0&currentPage=1&groupId=0"
browser.get(url)
print(browser.page_source)
# Out:
# C:\Users\user\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
# <html lang="ko" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36"><head><style type="text/css">@charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\:form{display:block;}.ng-animate-shim{visibility:hidden;}.ng-anchor{position:absolute;}</style>
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <base href="/home">
#     <meta name="robots" content="noindex,nofollow">
#     <meta name="referrer" content="always">
#     <meta name="format-detection" content="telephone=no">
#     <link rel="shortcut icon" type="image/x-icon" href="https://section.blog.naver.com/favicon.ico?3">
#
#
#
#
#
#
#
#
#
# ...

# %% [markdown]
# #### time 함수와 sleep()

# %%
from selenium import webdriver
browser = webdriver.Chrome("./chromedriver")
browser.get("https://section.blog.naver.com/BlogHome.nhn?directoryNo=0&currentPage=1&groupId=0")
import time
time.sleep(3)
print(browser.page_source)
# Out:
# C:\Users\user\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
# <html lang="ko" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36"><head><script async="" type="text/javascript" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-core.js"></script><style type="text/css">@charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\:form{display:block;}.ng-animate-shim{visibility:hidden;}.ng-anchor{position:absolute;}</style>
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <base href="/home">
#     <meta name="robots" content="noindex,nofollow">
#     <meta name="referrer" content="always">
#     <meta name="format-detection" content="telephone=no">
# ...

# %% [markdown]
# #### 로또문제 와 click()

# %%
from selenium import webdriver
browser = webdriver.Chrome("./chromedriver")
url="http://147.46.178.16:33333/javascript.html"
browser.get(url)
print(browser.page_source)
# Out:
# C:\Users\user\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
# <html><head></head><body><a href="javascript:openComments();">로또번호 생성하기</a>
# <div id="commentArea"></div>
#
# <script>
# 	var ddd = Math.random()
#   function openComments() {
#     a = "";
#     for (i = 0; i < 7; i++) {
#       a += Math.ceil(Math.random() * 45) + "<br>";
#     }
#     document.getElementById("commentArea").innerHTML = a;
#   }
#
#   function displayTime() {
#     document.getElementById('demo').innerHTML = Date()
#   }
#
# </script></body></html>

# %%
from selenium import webdriver
browser = webdriver.Chrome("./chromedriver")
browser.get("http://147.46.178.16:33333/javascript.html")

time.sleep(3)
browser.find_element_by_css_selector("body a").click()
print(browser.page_source)
# Out:
# C:\Users\user\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
# <html><head></head><body><a href="javascript:openComments();">로또번호 생성하기</a>
# <div id="commentArea">43<br>14<br>30<br>39<br>1<br>15<br>36<br></div>
#
# <script>
# 	var ddd = Math.random()
#   function openComments() {
#     a = "";
#     for (i = 0; i < 7; i++) {
#       a += Math.ceil(Math.random() * 45) + "<br>";
#     }
#     document.getElementById("commentArea").innerHTML = a;
#   }
#
#   function displayTime() {
#     document.getElementById('demo').innerHTML = Date()
#   }
#
# </script></body></html>
# C:\Users\user\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

browser = webdriver.Chrome("./chromedriver")
browser.get("http://147.46.178.16:33333/javascript.html")

time.sleep(3)
browser.find_element_by_css_selector("body a").click()
time.sleep(1)
html=browser.page_source

soup = BeautifulSoup(html, 'html.parser') 
numbers = soup.select('#commentArea')
numbers
# Out:
# C:\Users\user\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   after removing the cwd from sys.path.
# C:\Users\user\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# [<div id="commentArea">33<br/>35<br/>43<br/>8<br/>5<br/>15<br/>6<br/></div>]

# %%
numbers_revised=str(numbers[0]).split("<br/>")
numbers_revised
# Out:
# ['<div id="commentArea">33', '35', '43', '8', '5', '15', '6', '</div>']

# %%
for number in numbers_revised:
    print(number)
# Out:
# <div id="commentArea">33
# 35
# 43
# 8
# 5
# 15
# 6
# </div>

# %%
delete=['div', 'id="commentArea"', '<', '>', '/']
new=[]
for number in numbers_revised:
    for x in range(len(delete)):
        number=number.replace(delete[x], "")
    new.append(number)
new
# Out:
# [' 33', '35', '43', '8', '5', '15', '6', '']

# %% [markdown]
# #### 네이버스포츠 예제

# %%
from selenium import webdriver
#from selenium.webdriver.common.keys import Keys
from selenium import webdriver
from bs4 import BeautifulSoup

browser = webdriver.Chrome()
url="https://sports.news.naver.com/index.nhn"
browser.get(url)
boxes = browser.find_elements_by_css_selector(".today_item div.text_area")

#import time
#time.sleep(3)
for box in boxes:
    # title = browser.find~~~~`
    title = box.find_element_by_css_selector("strong.title") #기사타이틀
    newspaper = box.find_element_by_css_selector(".information span").text #신문사
    sport = box.find_element_by_css_selector(".information span:nth-child(2)").text #스포츠 상위 주제
    print(sport, newspaper, title.text)
# Out:
# C:\Users\user\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   if __name__ == '__main__':
# 해외축구 일반 스포티비뉴스 ‘팀도 상대 선수도 살렸다’ 하메스, 심정지 선수에 응급조치
# 프리미어리그 스타뉴스 '435억원만 줘' 토트넘 이적료 파격 세일, 'SON 동료' 가치 대폭락
# 여자 프로농구 서울신문 7분도 못 뛰는 3.3억 선수를 어쩌나… 고민 깊은 강아정 활용법
# KBO리그 OSEN ‘후회하게 만들까’ FA 보상선수 4총사, 누가 터질까...또 두산이려나
# KBO리그 엑스포츠뉴스 '은퇴부터 전향까지' 이대은·이학주·하재훈, 3년 만에 중대기로 선 '2019 유턴파'
# 메이저리그 스포티비뉴스 기다린 보람 있나? 김광현 '투자 대비 효과' 톱5 예상

# %% [markdown]
# ####  멜론 사이트 예제

# %%
#실습: 멜론 사이트 접속하기 

from selenium import webdriver
#from selenium.webdriver.common.keys import Keys
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Chrome()
url = 'http://www.melon.com/chart/index.htm'
driver.get(url)     

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
#반복문을 이용해 곡과 가수명을 song_data에 저장하기 
song_data = []
rank = 1

songs = soup.select('table > tbody > tr')
for song in songs:                                        
    title = song.select('div.rank01 > span > a')[0].text
    singer = song.select('div.rank02 > a')[0].text
    song_data.append(['Melon', rank, title, singer])
    rank = rank + 1

# %%
#song_data 리스트를 이용해 데이터프레임 만들기 
import pandas as pd
columns = ['서비스', '순위', '타이틀', '가수']
pd_data = pd.DataFrame(song_data, columns = columns)
pd_data
# Out:
#       서비스   순위                                     타이틀             가수
# 0   Melon    1                                    취중고백     김민석 (멜로망스)
# 1   Melon    2  회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)       sokodomo
# 2   Melon    3         Counting Stars (Feat. Beenzino)      BE'O (비오)
# 3   Melon    4           리무진 (Feat. MINO) (Prod. GRAY)      BE'O (비오)
# 4   Melon    5                                  ELEVEN      IVE (아이브)
# ..    ...  ...                                     ...            ...
# 95  Melon   96                               밤새 서로 미루다             존박
# 96  Melon   97                           Santa Tell Me  Ariana Grande
# 97  Melon   98                                 아직도 좋아해            양요섭
# 98  Melon   99                          너와 나의 Memories             염따
# 99  Melon  100             에잇(Prod.&Feat. SUGA of BTS)            아이유
#
# [100 rows x 4 columns]

# %% [markdown]
# #### 댓글추출

# %%
from selenium import webdriver

browser = webdriver.Chrome()

browser.get("https://news.naver.com/main/ranking/read.nhn?oid=011&aid=0003814563")
import time
time.sleep(1)
print(replies)
# Out:
# 562

# %% [markdown]
# #### send_key()와 click() 함수

# %%
from selenium import webdriver
browser = webdriver.Chrome()

browser.get("https://section.blog.naver.com/BlogHome.nhn?directoryNo=0&currentPage=1&groupId=0")

import time
time.sleep(1)
#textbox = browser.find_element_by_css_selector("div.area_dropdown + input.textbox")
textbox = browser.find_element_by_css_selector("input.textbox")
textbox.send_keys("피카츄")
time.sleep(2)

#browser.find_element_by_css_selector("i.sp_common.icon_search").click() <---아님!
browser.find_element_by_css_selector("a.button.button_blog").click()

time.sleep(1)
# Out:
# C:\Users\user\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   # Remove the CWD from sys.path while we load stuff.

# %%
from selenium import webdriver
browser = webdriver.Chrome()
from selenium.webdriver.common.keys import Keys

browser.get("https://section.blog.naver.com/BlogHome.nhn?directoryNo=0&currentPage=1&groupId=0")

import time
time.sleep(1)
#textbox = browser.find_element_by_css_selector("div.area_dropdown + input.textbox")
textbox = browser.find_element_by_css_selector("input.textbox")
textbox.send_keys("피카츄")
time.sleep(2)

#browser.find_element_by_css_selector("i.sp_common.icon_search").click() <---아님!
#browser.find_element_by_css_selector("a.button.button_blog").click()
textbox.send_keys(Keys.RETURN)   #enter 키 치는거 자동화임

time.sleep(1)

# %%
keywords = ["피카츄", "라이츄", "이상해씨"]
for keyword in keywords:
    print("https://section.blog.naver.com/Search/Post.nhn?pageNo=1&rangeType=ALL&orderBy=sim&keyword=" + keyword)
# Out:
# https://section.blog.naver.com/Search/Post.nhn?pageNo=1&rangeType=ALL&orderBy=sim&keyword=피카츄
# https://section.blog.naver.com/Search/Post.nhn?pageNo=1&rangeType=ALL&orderBy=sim&keyword=라이츄
# https://section.blog.naver.com/Search/Post.nhn?pageNo=1&rangeType=ALL&orderBy=sim&keyword=이상해씨

# %%
from selenium import webdriver
browser = webdriver.Chrome()


keywords = ["피카츄", "라이츄", "이상해씨"]
# listofPostAddresses = []
for keyword in keywords:
    for i in range(1, 5):
        address = "https://section.blog.naver.com/Search/Post.nhn?pageNo=" + str(i) + "&rangeType=ALL&orderBy=sim&keyword=" + keyword
        print(address)
        browser.get(address)
        import time
        time.sleep(3)
        titles = browser.find_elements_by_css_selector(".title_post .title")
        for title in titles:
            print(title.text)
            #print("\t" + title.text)
            # url = """dfdfdsfddf"""
            # listofPostAddresses.append(url)

# for url in listofPostAddresses:
#     browser.get(url)
# Out:
# https://section.blog.naver.com/Search/Post.nhn?pageNo=1&rangeType=ALL&orderBy=sim&keyword=피카츄
# C:\Users\user\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# 아이패드 드로잉, 피카츄 일러스트 그리기!
# [제품추천] 초등인싸템! 따뜻한 겨울을 위한 피카츄 핸드워머 (포켓몬스터손난로)
# 설악산 전람회능선 - 왕관봉 - 희야봉 - 피카츄바위 - 도깨비바위
# 피카츄배구 게임하기 [포켓몬온라인버전]
# 용인 기흥 구갈동 세븐토이 피규어 프라모델 전문점 방문기 포켓몬스터 귀염둥이 피카츄...
# 34. POKÉMON:LET’S GO PIKACHU!(포켓몬 레츠고 피카츄)
# 고양이 4남매 일상, 고양이 잇템 피카츄 방석과 매력점부자 삼색냥 제순이♡
# https://section.blog.naver.com/Search/Post.nhn?pageNo=2&rangeType=ALL&orderBy=sim&keyword=피카츄
# 포켓몬스터 피카츄 & 폿챠마 LED 룸 라이트
# 피카츄 만들기 - 아이클레이 피카피카!!
# 제주도 피카츄돈까스 in 깐돌이분식
# 말하고 걷는 피카츄 인형 :: 6살 아이 생일선물
# 학교앞분식집 피카츄돈까스 감성, 우리할매떡볶이 극찬!
# 포켓몬키즈 ~ 피카츄 피카피카 대집합 4,5
# 안성 스타필드 피카츄 위치 전시일정은 바로여기,,
# https://section.blog.naver.com/Search/Post.nhn?pageNo=3&rangeType=ALL&orderBy=sim&keyword=피카츄
# 일본컵라면 피카츄 라면 간장맛
# 피카츄 그리기, 색칠공부 도안 포함!
# ...

# %% [markdown]
# #### 탄지로 크롤러

# %%
from selenium import webdriver
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
driver = webdriver.Chrome()
driver.get('http://www.google.co.kr/imghp?hl=ko')
elem = driver.find_element_by_name("q")
elem.send_keys("탄지로")
elem.send_keys(Keys.RETURN)   #enter 키 치는거 자동화임


SCROLL_PAUSE_TIME = 1
# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)
    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        try:
            driver.find_element_by_css_selector(".mye4qd").click()
        except:
            break
    last_height = new_height

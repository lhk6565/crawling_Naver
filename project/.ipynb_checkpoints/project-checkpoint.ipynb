# %%
from selenium import webdriver
from selenium.webdriver import ActionChains
from bs4 import BeautifulSoup
import pandas as pd
browser = webdriver.Chrome()
#정왕동에서 시작
browser.get("https://new.land.naver.com/complexes/1887?ms=37.366011,126.7303085,17&a=APT:ABYG:JGC&e=RETAIL")


import time
#아래 팝업창 뜨게 하기(아래 세모버튼 누르기?) xpath 사용
browser.find_element_by_xpath('//*[@id="region_filter"]/div/a/span[4]').click()
time.sleep(3)

apt_data=[] #아파트 데이터를 담는 리스트
no_apt_data=[] #불러오지 못한 아파트 이름을 담는 리스트

#순차적으로 아래있는것을 클릭하게 함
for i in range(1, 67):
    pead_path = '//*[@id="region_filter"]/div/div/div[3]/ul/li[{0}]/a'.format(i)
    pead = browser.find_element_by_xpath(pead_path).click()
    time.sleep(3)
    
    #왼쪽에 있는첫번째것을 클릭
    #browser.find_element_by_css_selector("div.item_inner").click()
    #time.sleep(2)
    
    #광고가 뜨면 아파트 이름이 인식이 안되므로 try except 문 사용
    try:
        browser.find_element_by_css_selector("div.item_inner").click()
        time.sleep(2)
        #아파트 이름
        apt_name_path = 'div.main_info_area > div.info_title_wrap > h4 > strong'
        apt_name = browser.find_element_by_css_selector(apt_name_path)
        name = apt_name.text.split(" ")[0]
        #매매, 전세, 월세 구분
        apt_type_path = 'div.main_info_area > div.info_article_price > span.type'
        apt_type = browser.find_element_by_css_selector(apt_type_path)
        typ = apt_type.text
        #아파트 가격
        apt_price_path = 'div.main_info_area > div.info_article_price > span.price'
        apt_price = browser.find_element_by_css_selector(apt_price_path)
        price = apt_price.text
        #아파트 방향
        apt_way_path = 'div.detail_box--summary > table > tbody > tr:nth-child(6) > td'
        apt_way = browser.find_element_by_css_selector(apt_way_path)
        way = apt_way.text
        #관리비
        apt_mange_path = 'div.detail_box--summary > table > tbody > tr:nth-child(4) > td:nth-child(2)'
        apt_mange = browser.find_element_by_css_selector(apt_mange_path)
        mange = apt_mange.text
        #매물특징
        apt_feature_path = '//*[@id="detailContents1"]/div[1]/table/tbody/tr[1]/td'
        apt_feature = browser.find_element_by_xpath(apt_feature_path)
        feature = apt_feature.text
        #평수클릭
        browser.find_element_by_xpath('//*[@id="tabArea"]/button').click()
        time.sleep(1)
        #평수
        apt_space_path = 'div.detail_box--summary > table > tbody > tr:nth-child(2) > td'
        apt_space = browser.find_element_by_css_selector(apt_space_path)
        space = apt_space.text
        #층수
        apt_floor_path = 'div.detail_box--summary > table > tbody > tr:nth-child(3) > td:nth-child(2)'
        apt_floor = browser.find_element_by_css_selector(apt_floor_path)
        floor = apt_floor.text
        #학군정보 클릭
        browser.find_element_by_css_selector('.tab_area_list #detailTab4  span.text').click()
        time.sleep(2)
        #학군정보 학교이름
        school_name_path = '#detailContents5 > div > div.detail_box--school > div.heading > h5'
        school_name = browser.find_element_by_css_selector(school_name_path)
        school = school_name.text
        #학군정보 학교까지 거리
        school_distance_path = '//*[@id="detailContents5"]/div/div[1]/div[2]/div[2]/div[2]'
        school_distance = browser.find_element_by_xpath(school_distance_path)
        distance = school_distance.text
        #x버튼 누르기
        browser.find_element_by_css_selector("div.detail_panel > div > button").click()
        time.sleep(2)
        #아래 팝업창 뜨게 하기(아래 세모버튼 누르기?) xpath 사용
        browser.find_element_by_xpath('//*[@id="region_filter"]/div/a/span[4]').click()
        time.sleep(2)
        print(name, typ, price, way, mange, feature, space, floor, school, distance)
        apt_data.append([name, typ, price, way, mange, feature, space, floor, school, distance])
        
        
    #아파트 이름을 찾지 못할 때 x버튼을 누르고 다음 아파트 검색
    except:
        browser.find_element_by_css_selector("div.detail_panel > div > button").click()
        time.sleep(2)
        browser.find_element_by_xpath('//*[@id="region_filter"]/div/a/span[4]').click()
        time.sleep(2)
        test1_path = '//*[@id="region_filter"]/div/div/div[3]/ul/li[{0}]/a/span'.format(i)
        test1 = browser.find_element_by_xpath(test1_path)
        test2=test1.text
        print("불러오지 못한 아파트", test2)
        no_apt_data.append([test2])
# Out:
# C:\Users\lhk65\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   if sys.path[0] == '':
# C:\Users\lhk65\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:21: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# C:\Users\lhk65\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:30: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# C:\Users\lhk65\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:34: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# C:\Users\lhk65\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:38: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# C:\Users\lhk65\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:42: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# C:\Users\lhk65\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:46: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# C:\Users\lhk65\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:50: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# C:\Users\lhk65\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:54: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# C:\Users\lhk65\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:57: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# C:\Users\lhk65\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:61: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# C:\Users\lhk65\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:65: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# C:\Users\lhk65\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:68: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# C:\Users\lhk65\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:72: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# C:\Users\lhk65\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:76: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# C:\Users\lhk65\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:79: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# C:\Users\lhk65\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:82: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# 건영1차 전세 3억 3,000 남서향(거실 기준) 12만원 올수리되어 아주깨끗한집 .학교,상권가까워서 생활편리합니다.빠른입주가능 32.89평/25.69평(전용률78%) 10/10층 정왕초등학교 도보로 4분
# 건영2차 매매 3억 8,000 남동향(거실 기준) 18만원 올수리 올확장 전세끼고매매 협의 32.89평/25.69평(전용률78%) 10/10층 송운초등학교 도보로 6분
# 계룡1차 매매 4억 3,000 남서향(거실 기준) 15만원 약간수리된집 전망굿 상가인접생활권좋음 32.39평/25.7평(전용률79%) 4/10층 서촌초등학교 도보로 5분
# 계룡2차 매매 3억 남서향(거실 기준) 13만원 공시지가1억미만 투자물건 22.01평/18.1평(전용률82%) 5/5층 서해초등학교 도보로 8분
# 고합 매매 2억 8,500 남서향(거실 기준) 13만원 전체올수리. 거실확장. 안방붙박이장. 이사협의. 조정가 22.24평/18.13평(전용률82%) 4/5층 송운초등학교 도보로 6분
# 금강 매매 3억 3,000 남동향(거실 기준) 12만원 올수리되어 아주깨끗 이마트상권 초중교인접 22.36평/18.14평(전용률81%) 4/5층 정왕초등학교 도보로 6분
# 대림1단지 매매 4억 6,000 남서향(거실 기준) 20만원 세낀투자매물 올수리된깨끗한집 상권.교통.주변환경좋은매물 투자가치너무좋아요 32.21평/25.68평(전용률80%) 3/10층 서해초등학교 도보로 8분
# 대림2단지 매매 2억 5,000 남서향(거실 기준) 8만원 특올수리 방 거실확장 씽크대 화장실 올수샷시도공시지가1억이하 18.96평/15.49평(전용률82%) 5/5층 서촌초등학교 도보로 3분
#불러오지 못한 아파트 이름을 담는 리스트
no_apt_data
# Out:
# [['승창(도시형)'],
#  ['시화MTV파라곤'],
#  ['시화서촌마을건영3차'],
#  ['시흥금강펜테리움오션베이'],
#  ['신한토탈'],
#  ['영남2차'],
#  ['영남5차'],
#  ['오성(도시형)'],
#  ['주공3단지'],
#  ['호반써밋더퍼스트시흥'],
#  ['호반써밋더프라임']]

# %%
#아파트 데이터를 담는 리스트
apt_data
# Out:
# [['건영1차',
#   '전세',
#   '3억 3,000',
#   '남서향(거실 기준)',
#   '12만원',
#   '올수리되어 아주깨끗한집 .학교,상권가까워서 생활편리합니다.빠른입주가능',
#   '32.89평/25.69평(전용률78%)',
#   '10/10층',
#   '정왕초등학교',
#   '도보로 4분'],
#  ['건영2차',
#   '매매',
#   '3억 8,000',
#   '남동향(거실 기준)',
#   '18만원',
#   '올수리 올확장 전세끼고매매 협의',
#   '32.89평/25.69평(전용률78%)',
#   '10/10층',
#   '송운초등학교',
#   '도보로 6분'],
#  ['계룡1차',
#   '매매',
#   '4억 3,000',
#   '남서향(거실 기준)',
#   '15만원',
#   '약간수리된집 전망굿 상가인접생활권좋음',
#   '32.39평/25.7평(전용률79%)',
#   '4/10층',
#   '서촌초등학교',
#   '도보로 5분'],
#  ['계룡2차',
#   '매매',
#   '3억',
#   '남서향(거실 기준)',
#   '13만원',
#   '공시지가1억미만 투자물건',
#   '22.01평/18.1평(전용률82%)',
#   '5/5층',
#   '서해초등학교',
#   '도보로 8분'],
#  ['고합',
#   '매매',
#   '2억 8,500',
#   '남서향(거실 기준)',
#   '13만원',
#   '전체올수리. 거실확장. 안방붙박이장. 이사협의. 조정가',
#   '22.24평/18.13평(전용률82%)',
#   '4/5층',
#   '송운초등학교',
#   '도보로 6분'],
#  ['금강',
#   '매매',
#   '3억 3,000',
#   '남동향(거실 기준)',
#   '12만원',
#   '올수리되어 아주깨끗 이마트상권 초중교인접',
#   '22.36평/18.14평(전용률81%)',
#   '4/5층',
#   '정왕초등학교',
#   '도보로 6분'],
#  ['대림1단지',
#   '매매',
#   '4억 6,000',
#   '남서향(거실 기준)',
#   '20만원',
#   '세낀투자매물 올수리된깨끗한집 상권.교통.주변환경좋은매물 투자가치너무좋아요',
#   '32.21평/25.68평(전용률80%)',
#   '3/10층',
#   '서해초등학교',
#   '도보로 8분'],
#  ['대림2단지',
#   '매매',
#   '2억 5,000',
#   '남서향(거실 기준)',
#   '8만원',
#   '특올수리 방 거실확장 씽크대 화장실 올수샷시도공시지가1억이하',
#   '18.96평/15.49평(전용률82%)',
#   '5/5층',
#   '서촌초등학교',
#   '도보로 3분'],
#  ['대림3단지',
#   '매매',
#   '6억 5,000',
#   '계단식',
#   '2억4,600만원',
#   '공원뷰가 예쁜집입니다.',
#   '42.6평/35.46평(전용률83%)',
#   '1/10층',
#   '함현초등학교',
#   '도보로 5분'],
#  ['대림4단지',
#   '매매',
#   '5억 6,000',
#   '남동향(거실 기준)',
#   '24만원',
#   '특올수리한집, 역세권, 급매물',
#   '42.6평/35.46평(전용률83%)',
#   '1/10층',
#   '함현초등학교',
#   '도보로 2분'],
#  ['대우',
#   '전세',
#   '3억 3,000',
#   '계단식',
#   '없음',
#   '조정 전체샷시 폴딩샷시 특올수리 공실',
#   '32.74평/25.7평(전용률79%)',
#   '1/9층',
#   '정왕초등학교',
#   '도보로 1분'],
#  ['동남',
#   '매매',
#   '2억 8,000',
#   '남동향(거실 기준)',
#   '12만원',
#   '완전올수리 5월입주',
#   '23.16평/17.85평(전용률77%)',
#   '10/10층',
#   '서해초등학교',
#   '도보로 8분'],
#  ['동보',
#   '전세',
#   '3억 3,000',
#   '남서향(거실 기준)',
#   '19.9305만원',
#   '올수리 되어있어요 조용하고 환한집',
#   '29.78평/25.69평(전용률86%)',
#   '2/10층',
#   '서해초등학교',
#   '도보로 11분'],
#  ['동원',
#   '월세',
#   '2억/60',
#   '남서향(거실 기준)',
#   '21만원',
#   '오이도역, 배곧신도시 근접. 인근공원',
#   '36.48평/30.09평(전용률82%)',
#   '6/10층',
#   '함현초등학교',
#   '도보로 7분'],
#  ['두산',
#   '매매',
#   '3억 3,500',
#   '남서향(거실 기준)',
#   '10만원',
#   '올수리 집깨끗 협의이사 조정가능',
#   '23.51평/18.14평(전용률77%)',
#   '7/10층',
#   '정왕초등학교',
#   '도보로 3분'],
#  ['모아',
#   '전세',
#   '3억',
#   '남서향(거실 기준)',
#   '-',
#   '샤시까지 전체특올수리,공실,입주청소해줌.',
#   '23.98평/18.14평(전용률76%)',
#   '10/10층',
#   '송운초등학교',
#   '도보로 4분'],
#  ['무진',
#   '전세',
#   '1억 9,000',
#   '남서향(거실 기준)',
#   '10만원',
#   '즉시입주 새로화장실까지 완전올수리 전세대출가능',
#   '19.81평/16.52평(전용률83%)',
#   '1/5층',
#   '시화초등학교',
#   '도보로 8분'],
#  ['문영센스빌',
#   '매매',
#   '3억 4,000',
#   '남동향(거실 기준)',
#   '4만원',
#   '복층인테리어가능,전실0.욕실2,이사빨리가능',
#   '22.71평/18.12평(전용률80%)',
#   '5/5층',
#   '함현초등학교',
#   '도보로 9분'],
#  ['미주',
#   '매매',
#   '4억 8,500',
#   '남서향(거실 기준)',
#   '15만원',
#   '로얄동 샤시까지 특올수리',
#   '32.47평/25.67평(전용률79%)',
#   '9/10층',
#   '송운초등학교',
#   '도보로 3분'],
#  ['보성',
#   '전세',
#   '3억 5,000',
#   '남동향(거실 기준)',
#   '-',
#   '오이도초역세권 수리해드립니다.',
#   '32.97평/25.69평(전용률78%)',
#   '10/10층',
#   '함현초등학교',
#   '도보로 6분'],
#  ['부성파스텔',
#   '매매',
#   '5억',
#   '남서향(거실 기준)',
#   '21만원',
#   '전체올수리, 역세권, 급매물입니다',
#   '32.04평/25.7평(전용률80%)',
#   '3/10층',
#   '송운초등학교',
#   '도보로 3분'],
#  ['삼성',
#   '매매',
#   '3억 8,000',
#   '남서향(거실 기준)',
#   '19만원',
#   '급매.조정가.역세권.앞이 탁 트임.',
#   '32.14평/25.7평(전용률80%)',
#   '10/10층',
#   '냉정초등학교',
#   '도보로 7분'],
#  ['삼환',
#   '매매',
#   '3억 7,000',
#   '남서향(거실 기준)',
#   '13만원',
#   '수리해서 깨끗해요.초중교 인접.생활 편리.',
#   '25.33평/18.11평(전용률71%)',
#   '8/10층',
#   '송운초등학교',
#   '도보로 1분'],
#  ['서촌마을건영4단지',
#   '매매',
#   '4억 3,000',
#   '남서향(거실 기준)',
#   '20만원',
#   '수리된 깨끗한 매물입니다. 세입자와 이사협의',
#   '33.54평/25.69평(전용률77%)',
#   '9/10층',
#   '시흥초등학교',
#   '도보로 1분'],
#  ['서촌마을영화하이닉스',
#   '매매',
#   '4억 5,000',
#   '남서향(거실 기준)',
#   '20.7만원',
#   '최근 전체올수리한집',
#   '29.2평/25.5평(전용률87%)',
#   '2/10층',
#   '시흥초등학교',
#   '도보로 3분'],
#  ['서해1차',
#   '매매',
#   '4억 1,500',
#   '계단식',
#   '-',
#   '내외부 샷시부터 전체올수리',
#   '28.61평/25.7평(전용률90%)',
#   '5/5층',
#   '송운초등학교',
#   '도보로 8분'],
#  ['서해2차',
#   '전세',
#   '4억 8,000',
#   '계단식',
#   '없음',
#   '전망좋고 수리된 깨끗하고 좋은집 산책로 서해고 인접 생활권 편리',
#   '45.48평/40.81평(전용률90%)',
#   '8/10층',
#   '송운초등학교',
#   '도보로 7분'],
#  ['세종1차',
#   '매매',
#   '4억 5,000',
#   '남서향(거실 기준)',
#   '17만원',
#   '급매물 초역세권 전체올수리',
#   '29.64평/25.69평(전용률87%)',
#   '1/10층',
#   '함현초등학교',
#   '도보로 4분'],
#  ['세종2차',
#   '매매',
#   '2억 8,000',
#   '남동향(거실 기준)',
#   '16만원',
#   '급매물, 전세끼고 투자하세요',
#   '22.74평/18.11평(전용률80%)',
#   '5/5층',
#   '함현초등학교',
#   '도보로 7분'],
#  ['세종3차',
#   '매매',
#   '3억 8,000',
#   '남서향(거실 기준)',
#   '20만원',
#   '빠른입주가능합니다 조정가능 수리 집주인세대입니다 정왕고등학교근접',
#   '30.3평/25.71평(전용률85%)',
#   '2/5층',
#   '서촌초등학교',
#   '도보로 4분'],
#  ['스카이드림씨티(도시형)',
#   '월세',
#   '500/40',
#   '북향(안방 기준)',
#   '6만원',
#   '세입자거주중 빠른입주가능합니다',
#   '6.27평/3.91평(전용률62%)',
#   '8/14층',
#   '냉정초등학교',
#   '도보로 11분'],
#  ['시화유천',
#   '매매',
#   '3억 8,000',
#   '남서향(거실 기준)',
#   '15만원',
#   '올수리 중문 협의이사 가격조정가능',
#   '32.5평/25.62평(전용률79%)',
#   '6/10층',
#   '시화초등학교',
#   '도보로 6분'],
#  ['시화평안마을건영5차',
#   '매매',
#   '4억 5,000',
#   '남동향(거실 기준)',
#   '17만원',
#   '깨끗 주차넉넉 초중교단지,이마트 식자재마트 은행',
#   '29.11평/25.68평(전용률88%)',
#   '7/10층',
#   '정왕초등학교',
#   '도보로 2분'],
#  ['신동아1단지',
#   '매매',
#   '2억 9,500',
#   '남동향(거실 기준)',
#   '10만원',
#   '공시지가1억미만아파트.전세13,650만원안고.',
#   '22평/18.08평(전용률82%)',
#   '1/5층',
#   '서해초등학교',
#   '도보로 7분'],
#  ['신동아2단지',
#   '전세',
#   '2억 2,000',
#   '남서향(거실 기준)',
#   '10만원',
#   '1층이지만 일조권좋음.수리되어있음.서해초,중,고인근.하시',
#   '22평/18.08평(전용률82%)',
#   '1/5층',
#   '서해초등학교',
#   '도보로 7분'],
#  ['신우',
#   '매매',
#   '3억 1,500',
#   '남서향(거실 기준)',
#   '15만원',
#   '급매 조정가 전체 올수리',
#   '30.2평/25.69평(전용률85%)',
#   '5/5층',
#   '시흥초등학교',
#   '도보로 5분'],
#  ['신호새피앙',
#   '전세',
#   '4억 4,000',
#   '남동향(거실 기준)',
#   '20만원',
#   '즉시입주 가능함 씽크대 교체 저렴한매물',
#   '50.52평/40.81평(전용률81%)',
#   '5/10층',
#   '서해초등학교',
#   '도보로 2분'],
#  ['아주',
#   '전세',
#   '2억 8,000',
#   '남서향(거실 기준)',
#   '19만원',
#   '올수리해서 깨끗해요.역세권.대형병원,마트 인접.',
#   '31.14평/25.46평(전용률82%)',
#   '21/25층',
#   '냉정초등학교',
#   '도보로 9분'],
#  ['영남1차',
#   '매매',
#   '2억 8,000',
#   '남서향(거실 기준)',
#   '15만원',
#   '입주가능해요. 구조좋아요. 위치좋아요. 교통편리. 학세권',
#   '22.19평/18.14평(전용률82%)',
#   '4/5층',
#   '송운초등학교',
#   '도보로 6분'],
#  ['영남3차',
#   '전세',
#   '2억 5,000',
#   '남서향(거실 기준)',
#   '13만원',
#   '올수리해서 깨끗해요.역세권.',
#   '23.84평/18.11평(전용률76%)',
#   '8/10층',
#   '냉정초등학교',
#   '도보로 3분'],
#  ['영남4차',
#   '매매',
#   '3억 2,000',
#   '남서향(거실 기준)',
#   '16만원',
#   '올수리해서 깨끗해요.역세권.대형병원,마트 인접.',
#   '23.68평/18.11평(전용률77%)',
#   '6/10층',
#   '냉정초등학교',
#   '도보로 11분'],
#  ['영남6차',
#   '전세',
#   '3억',
#   '남동향(거실 기준)',
#   '15만원',
#   '올수리후 첫입주, 빠른이사, 상권가까워서 생활권편리, 전세대출가능',
#   '24.48평/18.14평(전용률74%)',
#   '3/10층',
#   '정왕초등학교',
#   '도보로 5분'],
#  ['옥구마을건영7차',
#   '매매',
#   '4억 5,000',
#   '남동향(거실 기준)',
#   '18만원',
#   '부분수리되어 깨끗하고 상권 학교인근',
#   '33.29평/25.69평(전용률77%)',
#   '8/10층',
#   '서해초등학교',
#   '도보로 1분'],
#  ['요진',
#   '매매',
#   '4억 2,000',
#   '남동향(거실 기준)',
#   '20만원',
#   '샤시포함올수리, 방1확장, 중문설치, 폴딩도어, 로얄동,로얄층',
#   '33.31평/25.67평(전용률77%)',
#   '5/10층',
#   '서촌초등학교',
#   '도보로 4분'],
#  ['월드',
#   '매매',
#   '3억 4,000',
#   '남서향(거실 기준)',
#   '10만원',
#   '역세권 최근 수리됨 월세낀 투자매물입니다',
#   '23.55평/18.12평(전용률77%)',
#   '2/10층',
#   '냉정초등학교',
#   '도보로 6분'],
#  ['주공1단지',
#   '매매',
#   '3억 4,000',
#   '남향(거실 기준)',
#   '15만원',
#   '방3 리모델링한깨끗한집 식기세척기 초.중낀학세권 생활편의시설굿 교통편리',
#   '24.38평/18.01평(전용률74%)',
#   '고/10층',
#   '서해초등학교',
#   '도보로 1분'],
#  ['주공2단지',
#   '전세',
#   '3억 1,000',
#   '남서향(거실 기준)',
#   '21만원',
#   '최근올수리 빠른입주가능 초중고인접 집상태최상',
#   '31.44평/25.6평(전용률81%)',
#   '5/10층',
#   '시흥초등학교',
#   '도보로 5분'],
#  ['주공4단지',
#   '매매',
#   '3억 2,000',
#   '동향(거실 기준)',
#   '13만원',
#   '욕실등 수리.조정가.역세권.',
#   '22.07평/18.02평(전용률82%)',
#   '3/5층',
#   '시흥초등학교',
#   '도보로 3분'],
#  ['주공5단지',
#   '매매',
#   '5억 1,000',
#   '남서향(거실 기준)',
#   '15만원',
#   '올수리,즉시입주가능',
#   '32.55평/25.66평(전용률79%)',
#   '8/10층',
#   '시흥초등학교',
#   '도보로 3분'],
#  ['주공6단지',
#   '매매',
#   '3억',
#   '남동향(거실 기준)',
#   '12만원',
#   '올수리 주인거주 협의이사',
#   '23.71평/18.13평(전용률76%)',
#   '2/10층',
#   '정왕초등학교',
#   '도보로 2분'],
#  ['진로',
#   '매매',
#   '2억 9,500',
#   '남서향(거실 기준)',
#   '13만원',
#   '초급매.수리해서 깨끗해요.',
#   '23.47평/17.93평(전용률76%)',
#   '9/10층',
#   '서촌초등학교',
#   '도보로 3분'],
#  ['청솔',
#   '전세',
#   '2억 2,000',
#   '남서향(거실 기준)',
#   '10만원',
#   '로얄층 전부 올수리로 깨끗함',
#   '19.23평/14.65평(전용률76%)',
#   '6/10층',
#   '서촌초등학교',
#   '도보로 5분'],
#  ['한신',
#   '매매',
#   '3억 3,000',
#   '남향(거실 기준)',
#   '10만원',
#   '2년전특올수리',
#   '23.61평/18.08평(전용률77%)',
#   '7/10층',
#   '냉정초등학교',
#   '도보로 6분'],
#  ['한일',
#   '전세',
#   '2억 3,000',
#   '남서향(거실 기준)',
#   '12만원',
#   '날짜협의,거실,작은방확장,수리되어 집상태 양호,조용한 남서향.',
#   '22.02평/17.92평(전용률81%)',
#   '2/5층',
#   '서해초등학교',
#   '도보로 3분'],
#  ['화성',
#   '월세',
#   '3,000/120',
#   '계단식',
#   '없음',
#   '새로 전체올수리 함 공실 보증금조정가',
#   '32.22평/25.68평(전용률80%)',
#   '10/10층',
#   '냉정초등학교',
#   '도보로 2분']]

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
driver = webdriver.Chrome()

url = "https://new.land.naver.com/complexes/113317?ms=37.3525,126.7279,16&a=APT:ABYG:JGC&e=RETAIL"
driver.get(url)
driver.find_element_by_xpath('//*[@id="region_filter"]/div/a/span[4]').click()
time.sleep(1)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
time.sleep(3)

prod_items = soup.select('a.complex_item_inner')
len(prod_items)
# Out:
# C:\Users\lhk65\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# 66

# %%
#변수에 저장
no_item_list = len(prod_items)
no_item_list
# Out:
# 66

# %%
#불러오지 못한 아파트 갯수를 불러온다
no=len(no_apt_data)
print(no)
# Out:
# 11

# %%
#불러온 아파트 갯수를 반환해주는 함수
def no_find_apt():
    no_find_list = no_item_list - no
    return no_find_list

no_find_apt()
# Out:
# 55

# %%
print("전체", no_item_list, "개 중에 출력된 아파트는", no_find_apt(), "개, 출력하지 못한 아파트는", no, "개 입니다.")
# Out:
# 전체 66 개 중에 출력된 아파트는 55 개, 출력하지 못한 아파트는 11 개 입니다.

# %%
#DataFrame으로 정리 후 액셀로 저장
from pandas import Series, DataFrame
import pandas as pd
columns = ['이름', '구분', '가격', '방향', '관리비', '매물특징', '평수', '층수', '학교명', '학교까지 거리']
pd_data = pd.DataFrame(apt_data, columns = columns)
display(pd_data)
pd_data.to_excel('./mange1.xlsx', index = False)
# Out:
#               이름  구분         가격          방향        관리비  \
# 0           건영1차  전세   3억 3,000  남서향(거실 기준)       12만원
# 1           건영2차  매매   3억 8,000  남동향(거실 기준)       18만원
# 2           계룡1차  매매   4억 3,000  남서향(거실 기준)       15만원
# 3           계룡2차  매매         3억  남서향(거실 기준)       13만원
# 4             고합  매매   2억 8,500  남서향(거실 기준)       13만원
# 5             금강  매매   3억 3,000  남동향(거실 기준)       12만원
# 6          대림1단지  매매   4억 6,000  남서향(거실 기준)       20만원
# 7          대림2단지  매매   2억 5,000  남서향(거실 기준)        8만원
# 8          대림3단지  매매   6억 5,000         계단식  2억4,600만원
# 9          대림4단지  매매   5억 6,000  남동향(거실 기준)       24만원
# 10            대우  전세   3억 3,000         계단식         없음
# 11            동남  매매   2억 8,000  남동향(거실 기준)       12만원
# 12            동보  전세   3억 3,000  남서향(거실 기준)  19.9305만원
# 13            동원  월세      2억/60  남서향(거실 기준)       21만원
# 14            두산  매매   3억 3,500  남서향(거실 기준)       10만원
# 15            모아  전세         3억  남서향(거실 기준)          -
# 16            무진  전세   1억 9,000  남서향(거실 기준)       10만원
# 17         문영센스빌  매매   3억 4,000  남동향(거실 기준)        4만원
# 18            미주  매매   4억 8,500  남서향(거실 기준)       15만원
# 19            보성  전세   3억 5,000  남동향(거실 기준)          -
# 20         부성파스텔  매매         5억  남서향(거실 기준)       21만원
# 21            삼성  매매   3억 8,000  남서향(거실 기준)       19만원
# 22            삼환  매매   3억 7,000  남서향(거실 기준)       13만원
# 23     서촌마을건영4단지  매매   4억 3,000  남서향(거실 기준)       20만원
# 24    서촌마을영화하이닉스  매매   4억 5,000  남서향(거실 기준)     20.7만원
# 25          서해1차  매매   4억 1,500         계단식          -
# 26          서해2차  전세   4억 8,000         계단식         없음
# 27          세종1차  매매   4억 5,000  남서향(거실 기준)       17만원
# 28          세종2차  매매   2억 8,000  남동향(거실 기준)       16만원
# 29          세종3차  매매   3억 8,000  남서향(거실 기준)       20만원
# 30  스카이드림씨티(도시형)  월세     500/40   북향(안방 기준)        6만원
# 31          시화유천  매매   3억 8,000  남서향(거실 기준)       15만원
# 32    시화평안마을건영5차  매매   4억 5,000  남동향(거실 기준)       17만원
# 33        신동아1단지  매매   2억 9,500  남동향(거실 기준)       10만원
# 34        신동아2단지  전세   2억 2,000  남서향(거실 기준)       10만원
# 35            신우  매매   3억 1,500  남서향(거실 기준)       15만원
# 36         신호새피앙  전세   4억 4,000  남동향(거실 기준)       20만원
# 37            아주  전세   2억 8,000  남서향(거실 기준)       19만원
# 38          영남1차  매매   2억 8,000  남서향(거실 기준)       15만원
# 39          영남3차  전세   2억 5,000  남서향(거실 기준)       13만원
# 40          영남4차  매매   3억 2,000  남서향(거실 기준)       16만원
# 41          영남6차  전세         3억  남동향(거실 기준)       15만원
# 42      옥구마을건영7차  매매   4억 5,000  남동향(거실 기준)       18만원
# 43            요진  매매   4억 2,000  남동향(거실 기준)       20만원
# 44            월드  매매   3억 4,000  남서향(거실 기준)       10만원
# 45         주공1단지  매매   3억 4,000   남향(거실 기준)       15만원
# 46         주공2단지  전세   3억 1,000  남서향(거실 기준)       21만원
# 47         주공4단지  매매   3억 2,000   동향(거실 기준)       13만원
# 48         주공5단지  매매   5억 1,000  남서향(거실 기준)       15만원
# 49         주공6단지  매매         3억  남동향(거실 기준)       12만원
# 50            진로  매매   2억 9,500  남서향(거실 기준)       13만원
# 51            청솔  전세   2억 2,000  남서향(거실 기준)       10만원
# 52            한신  매매   3억 3,000   남향(거실 기준)       10만원
# 53            한일  전세   2억 3,000  남서향(거실 기준)       12만원
# 54            화성  월세  3,000/120         계단식         없음
#
#                                         매물특징                     평수      층수  \
# 0     올수리되어 아주깨끗한집 .학교,상권가까워서 생활편리합니다.빠른입주가능  32.89평/25.69평(전용률78%)  10/10층
# 1                          올수리 올확장 전세끼고매매 협의  32.89평/25.69평(전용률78%)  10/10층
# 2                       약간수리된집 전망굿 상가인접생활권좋음   32.39평/25.7평(전용률79%)   4/10층
# 3                              공시지가1억미만 투자물건   22.01평/18.1평(전용률82%)    5/5층
# 4             전체올수리. 거실확장. 안방붙박이장. 이사협의. 조정가  22.24평/18.13평(전용률82%)    4/5층
# 5                     올수리되어 아주깨끗 이마트상권 초중교인접  22.36평/18.14평(전용률81%)    4/5층
# 6   세낀투자매물 올수리된깨끗한집 상권.교통.주변환경좋은매물 투자가치너무좋아요  32.21평/25.68평(전용률80%)   3/10층
# 7          특올수리 방 거실확장 씽크대 화장실 올수샷시도공시지가1억이하  18.96평/15.49평(전용률82%)    5/5층
# 8                               공원뷰가 예쁜집입니다.   42.6평/35.46평(전용률83%)   1/10층
# 9                           특올수리한집, 역세권, 급매물   42.6평/35.46평(전용률83%)   1/10층
# 10                      조정 전체샷시 폴딩샷시 특올수리 공실   32.74평/25.7평(전용률79%)    1/9층
# 41      올수리후 첫입주, 빠른이사, 상권가까워서 생활권편리, 전세대출가능  24.48평/18.14평(전용률74%)   3/10층
# 42                       부분수리되어 깨끗하고 상권 학교인근  33.29평/25.69평(전용률77%)   8/10층
# 43        샤시포함올수리, 방1확장, 중문설치, 폴딩도어, 로얄동,로얄층  33.31평/25.67평(전용률77%)   5/10층
# 44                    역세권 최근 수리됨 월세낀 투자매물입니다  23.55평/18.12평(전용률77%)   2/10층
# 45   방3 리모델링한깨끗한집 식기세척기 초.중낀학세권 생활편의시설굿 교통편리  24.38평/18.01평(전용률74%)   고/10층
# 46                  최근올수리 빠른입주가능 초중고인접 집상태최상   31.44평/25.6평(전용률81%)   5/10층
# 47                           욕실등 수리.조정가.역세권.  22.07평/18.02평(전용률82%)    3/5층
# 48                                올수리,즉시입주가능  32.55평/25.66평(전용률79%)   8/10층
# 49                             올수리 주인거주 협의이사  23.71평/18.13평(전용률76%)   2/10층
# 50                            초급매.수리해서 깨끗해요.  23.47평/17.93평(전용률76%)   9/10층
# 51                           로얄층 전부 올수리로 깨끗함  19.23평/14.65평(전용률76%)   6/10층
# 52                                   2년전특올수리  23.61평/18.08평(전용률77%)   7/10층
# 53        날짜협의,거실,작은방확장,수리되어 집상태 양호,조용한 남서향.  22.02평/17.92평(전용률81%)    2/5층
# 54                      새로 전체올수리 함 공실 보증금조정가  32.22평/25.68평(전용률80%)  10/10층
#
#        학교명  학교까지 거리
# 0   정왕초등학교   도보로 4분
# 1   송운초등학교   도보로 6분
# 2   서촌초등학교   도보로 5분
# 3   서해초등학교   도보로 8분
# 4   송운초등학교   도보로 6분
# 5   정왕초등학교   도보로 6분
# 6   서해초등학교   도보로 8분
# 7   서촌초등학교   도보로 3분
# 8   함현초등학교   도보로 5분
# 9   함현초등학교   도보로 2분
# 10  정왕초등학교   도보로 1분
# 11  서해초등학교   도보로 8분
# 12  서해초등학교  도보로 11분
# 13  함현초등학교   도보로 7분
# 14  정왕초등학교   도보로 3분
# 15  송운초등학교   도보로 4분
# 16  시화초등학교   도보로 8분
# 17  함현초등학교   도보로 9분
# 18  송운초등학교   도보로 3분
# 19  함현초등학교   도보로 6분
# 20  송운초등학교   도보로 3분
# 21  냉정초등학교   도보로 7분
# 22  송운초등학교   도보로 1분
# 23  시흥초등학교   도보로 1분
# 24  시흥초등학교   도보로 3분
# 25  송운초등학교   도보로 8분
# 26  송운초등학교   도보로 7분
# 27  함현초등학교   도보로 4분
# 28  함현초등학교   도보로 7분
# 29  서촌초등학교   도보로 4분
# 30  냉정초등학교  도보로 11분
# 31  시화초등학교   도보로 6분
# 32  정왕초등학교   도보로 2분
# 33  서해초등학교   도보로 7분
# 34  서해초등학교   도보로 7분
# 35  시흥초등학교   도보로 5분
# 36  서해초등학교   도보로 2분
# 37  냉정초등학교   도보로 9분
# 38  송운초등학교   도보로 6분
# 39  냉정초등학교   도보로 3분
# 40  냉정초등학교  도보로 11분
# 41  정왕초등학교   도보로 5분
# 42  서해초등학교   도보로 1분
# 43  서촌초등학교   도보로 4분
# 44  냉정초등학교   도보로 6분
# 45  서해초등학교   도보로 1분
# 46  시흥초등학교   도보로 5분
# 47  시흥초등학교   도보로 3분
# 48  시흥초등학교   도보로 3분
# 49  정왕초등학교   도보로 2분
# 50  서촌초등학교   도보로 3분
# 51  서촌초등학교   도보로 5분
# 52  냉정초등학교   도보로 6분
# 53  서해초등학교   도보로 3분
# 54  냉정초등학교   도보로 2분

# %%
#액셀의 특정열 리스트로 변환하기(이름, 관리비)
from openpyxl import load_workbook


read_xlsx = load_workbook('mange1.xlsx')
read_sheet = read_xlsx.active


name_col = read_sheet['E']
names = []
for cell in name_col:
    names.append(cell.value)
print(names)
name1_col = read_sheet['A']
realNames = []
for cell1 in name1_col:
    realNames.append(cell1.value)
print(realNames)
# Out:
# ['관리비', '12만원', '18만원', '15만원', '13만원', '13만원', '12만원', '20만원', '8만원', '2억4,600만원', '24만원', '없음', '12만원', '19.9305만원', '21만원', '10만원', '-', '10만원', '4만원', '15만원', '-', '21만원', '19만원', '13만원', '20만원', '20.7만원', '-', '없음', '17만원', '16만원', '20만원', '6만원', '15만원', '17만원', '10만원', '10만원', '15만원', '20만원', '19만원', '15만원', '13만원', '16만원', '15만원', '18만원', '20만원', '10만원', '15만원', '21만원', '13만원', '15만원', '12만원', '13만원', '10만원', '10만원', '12만원', '없음']
# ['이름', '건영1차', '건영2차', '계룡1차', '계룡2차', '고합', '금강', '대림1단지', '대림2단지', '대림3단지', '대림4단지', '대우', '동남', '동보', '동원', '두산', '모아', '무진', '문영센스빌', '미주', '보성', '부성파스텔', '삼성', '삼환', '서촌마을건영4단지', '서촌마을영화하이닉스', '서해1차', '서해2차', '세종1차', '세종2차', '세종3차', '스카이드림씨티(도시형)', '시화유천', '시화평안마을건영5차', '신동아1단지', '신동아2단지', '신우', '신호새피앙', '아주', '영남1차', '영남3차', '영남4차', '영남6차', '옥구마을건영7차', '요진', '월드', '주공1단지', '주공2단지', '주공4단지', '주공5단지', '주공6단지', '진로', '청솔', '한신', '한일', '화성']

# %%
#이름과 관리비 리스트에서 필요없는 부분 제거
names.remove('관리비')
print(names)
realNames.remove('이름')
print(realNames)
# Out:
# ['12만원', '18만원', '15만원', '13만원', '13만원', '12만원', '20만원', '8만원', '2억4,600만원', '24만원', '없음', '12만원', '19.9305만원', '21만원', '10만원', '-', '10만원', '4만원', '15만원', '-', '21만원', '19만원', '13만원', '20만원', '20.7만원', '-', '없음', '17만원', '16만원', '20만원', '6만원', '15만원', '17만원', '10만원', '10만원', '15만원', '20만원', '19만원', '15만원', '13만원', '16만원', '15만원', '18만원', '20만원', '10만원', '15만원', '21만원', '13만원', '15만원', '12만원', '13만원', '10만원', '10만원', '12만원', '없음']
# ['건영1차', '건영2차', '계룡1차', '계룡2차', '고합', '금강', '대림1단지', '대림2단지', '대림3단지', '대림4단지', '대우', '동남', '동보', '동원', '두산', '모아', '무진', '문영센스빌', '미주', '보성', '부성파스텔', '삼성', '삼환', '서촌마을건영4단지', '서촌마을영화하이닉스', '서해1차', '서해2차', '세종1차', '세종2차', '세종3차', '스카이드림씨티(도시형)', '시화유천', '시화평안마을건영5차', '신동아1단지', '신동아2단지', '신우', '신호새피앙', '아주', '영남1차', '영남3차', '영남4차', '영남6차', '옥구마을건영7차', '요진', '월드', '주공1단지', '주공2단지', '주공4단지', '주공5단지', '주공6단지', '진로', '청솔', '한신', '한일', '화성']

# %%
#관리비 리스트에서 뒤에 만원 글자 제거
search = '만원'
for i, word in enumerate(names):
    if search in word: 
        print('>> modify: ' + word)
        names[i] = word.strip(search)
print(names)
# Out:
# >> modify: 12만원
# >> modify: 18만원
# >> modify: 15만원
# >> modify: 13만원
# >> modify: 13만원
# >> modify: 12만원
# >> modify: 20만원
# >> modify: 8만원
# >> modify: 2억4,600만원
# >> modify: 24만원
# >> modify: 12만원
# >> modify: 19.9305만원
# >> modify: 21만원
# >> modify: 10만원
# >> modify: 10만원
# >> modify: 4만원
# >> modify: 15만원
# >> modify: 21만원
# >> modify: 19만원
# >> modify: 13만원
# >> modify: 20만원
# >> modify: 20.7만원
# >> modify: 17만원
# >> modify: 16만원
# >> modify: 20만원
# >> modify: 6만원
# >> modify: 15만원
# >> modify: 17만원
# >> modify: 10만원
# >> modify: 10만원
# >> modify: 15만원
# >> modify: 20만원
# >> modify: 19만원
# >> modify: 15만원
# >> modify: 13만원
# >> modify: 16만원
# >> modify: 15만원
# >> modify: 18만원
# >> modify: 20만원
# >> modify: 10만원
# >> modify: 15만원
# >> modify: 21만원
# >> modify: 13만원
# >> modify: 15만원
# >> modify: 12만원
# >> modify: 13만원
# >> modify: 10만원
# >> modify: 10만원
# >> modify: 12만원
# ['12', '18', '15', '13', '13', '12', '20', '8', '2억4,600', '24', '없음', '12', '19.9305', '21', '10', '-', '10', '4', '15', '-', '21', '19', '13', '20', '20.7', '-', '없음', '17', '16', '20', '6', '15', '17', '10', '10', '15', '20', '19', '15', '13', '16', '15', '18', '20', '10', '15', '21', '13', '15', '12', '13', '10', '10', '12', '없음']

# %%
#값이 없는것과 '-'인 값을 0으로 변환
def change_names(names):
    for index, value in enumerate(names):
        if value == '없음':
            names[index] = 0
        if value == '-':
            names[index] = 0
        if value == '2억4,600':
            names[index] = 0
change_names(names)

# %%
names
# Out:
# ['12',
#  '18',
#  '15',
#  '13',
#  '13',
#  '12',
#  '20',
#  '8',
#  0,
#  '24',
#  0,
#  '12',
#  '19.9305',
#  '21',
#  '10',
#  0,
#  '10',
#  '4',
#  '15',
#  0,
#  '21',
#  '19',
#  '13',
#  '20',
#  '20.7',
#  0,
#  0,
#  '17',
#  '16',
#  '20',
#  '6',
#  '15',
#  '17',
#  '10',
#  '10',
#  '15',
#  '20',
#  '19',
#  '15',
#  '13',
#  '16',
#  '15',
#  '18',
#  '20',
#  '10',
#  '15',
#  '21',
#  '13',
#  '15',
#  '12',
#  '13',
#  '10',
#  '10',
#  '12',
#  0]

# %%
#관리비 리스트에서 문자열을 float형으로 변환
mange_int = list(map(float, names))
print(mange_int)
# Out:
# [12.0, 18.0, 15.0, 13.0, 13.0, 12.0, 20.0, 8.0, 0.0, 24.0, 0.0, 12.0, 19.9305, 21.0, 10.0, 0.0, 10.0, 4.0, 15.0, 0.0, 21.0, 19.0, 13.0, 20.0, 20.7, 0.0, 0.0, 17.0, 16.0, 20.0, 6.0, 15.0, 17.0, 10.0, 10.0, 15.0, 20.0, 19.0, 15.0, 13.0, 16.0, 15.0, 18.0, 20.0, 10.0, 15.0, 21.0, 13.0, 15.0, 12.0, 13.0, 10.0, 10.0, 12.0, 0.0]

# %%
#numpy round를 사용하여 반올림
import numpy as np
mange_round = np.round(mange_int,0)
mange_round
# Out:
# array([12., 18., 15., 13., 13., 12., 20.,  8.,  0., 24.,  0., 12., 20.,
#        21., 10.,  0., 10.,  4., 15.,  0., 21., 19., 13., 20., 21.,  0.,
#         0., 17., 16., 20.,  6., 15., 17., 10., 10., 15., 20., 19., 15.,
#        13., 16., 15., 18., 20., 10., 15., 21., 13., 15., 12., 13., 10.,
#        10., 12.,  0.])

# %%
#이름 리스트 출력
print(realNames)
# Out:
# ['건영1차', '건영2차', '계룡1차', '계룡2차', '고합', '금강', '대림1단지', '대림2단지', '대림3단지', '대림4단지', '대우', '동남', '동보', '동원', '두산', '모아', '무진', '문영센스빌', '미주', '보성', '부성파스텔', '삼성', '삼환', '서촌마을건영4단지', '서촌마을영화하이닉스', '서해1차', '서해2차', '세종1차', '세종2차', '세종3차', '스카이드림씨티(도시형)', '시화유천', '시화평안마을건영5차', '신동아1단지', '신동아2단지', '신우', '신호새피앙', '아주', '영남1차', '영남3차', '영남4차', '영남6차', '옥구마을건영7차', '요진', '월드', '주공1단지', '주공2단지', '주공4단지', '주공5단지', '주공6단지', '진로', '청솔', '한신', '한일', '화성']

# %%
#관리비 리스트 출력
print(mange_round)
# Out:
# [12. 18. 15. 13. 13. 12. 20.  8.  0. 24.  0. 12. 20. 21. 10.  0. 10.  4.
#  15.  0. 21. 19. 13. 20. 21.  0.  0. 17. 16. 20.  6. 15. 17. 10. 10. 15.
#  20. 19. 15. 13. 16. 15. 18. 20. 10. 15. 21. 13. 15. 12. 13. 10. 10. 12.
#   0.]

# %%
import pandas as pd
apt_names_df = pd.DataFrame(realNames, columns = ['아파트'])
apt_mange_df = pd.DataFrame(mange_round, columns = ['관리비'])

# %%
result = pd.concat([apt_names_df,apt_mange_df],axis=1)
result
# Out:
#              아파트   관리비
# 0           건영1차  12.0
# 1           건영2차  18.0
# 2           계룡1차  15.0
# 3           계룡2차  13.0
# 4             고합  13.0
# 5             금강  12.0
# 6          대림1단지  20.0
# 7          대림2단지   8.0
# 8          대림3단지   0.0
# 9          대림4단지  24.0
# 10            대우   0.0
# 11            동남  12.0
# 12            동보  20.0
# 13            동원  21.0
# 14            두산  10.0
# 15            모아   0.0
# 16            무진  10.0
# 17         문영센스빌   4.0
# 18            미주  15.0
# 19            보성   0.0
# 20         부성파스텔  21.0
# 21            삼성  19.0
# 22            삼환  13.0
# 23     서촌마을건영4단지  20.0
# 24    서촌마을영화하이닉스  21.0
# 25          서해1차   0.0
# 26          서해2차   0.0
# 27          세종1차  17.0
# 28          세종2차  16.0
# 29          세종3차  20.0
# 30  스카이드림씨티(도시형)   6.0
# 31          시화유천  15.0
# 32    시화평안마을건영5차  17.0
# 33        신동아1단지  10.0
# 34        신동아2단지  10.0
# 35            신우  15.0
# 36         신호새피앙  20.0
# 37            아주  19.0
# 38          영남1차  15.0
# 39          영남3차  13.0
# 40          영남4차  16.0
# 41          영남6차  15.0
# 42      옥구마을건영7차  18.0
# 43            요진  20.0
# 44            월드  10.0
# 45         주공1단지  15.0
# 46         주공2단지  21.0
# 47         주공4단지  13.0
# 48         주공5단지  15.0
# 49         주공6단지  12.0
# 50            진로  13.0
# 51            청솔  10.0
# 52            한신  10.0
# 53            한일  12.0
# 54            화성   0.0

# %%
result_1 = result.sort_values(by='관리비', ascending=False).head(20)
result_1
# Out:
#            아파트   관리비
# 9        대림4단지  24.0
# 46       주공2단지  21.0
# 24  서촌마을영화하이닉스  21.0
# 20       부성파스텔  21.0
# 13          동원  21.0
# 36       신호새피앙  20.0
# 29        세종3차  20.0
# 6        대림1단지  20.0
# 23   서촌마을건영4단지  20.0
# 43          요진  20.0
# 12          동보  20.0
# 37          아주  19.0
# 21          삼성  19.0
# 1         건영2차  18.0
# 42    옥구마을건영7차  18.0
# 27        세종1차  17.0
# 32  시화평안마을건영5차  17.0
# 28        세종2차  16.0
# 40        영남4차  16.0
# 41        영남6차  15.0

# %%
result_2 = result_1.reset_index(drop=True)
result_2
# Out:
#            아파트   관리비
# 0        대림4단지  24.0
# 1        주공2단지  21.0
# 2   서촌마을영화하이닉스  21.0
# 3        부성파스텔  21.0
# 4           동원  21.0
# 5        신호새피앙  20.0
# 6         세종3차  20.0
# 7        대림1단지  20.0
# 8    서촌마을건영4단지  20.0
# 9           요진  20.0
# 10          동보  20.0
# 11          아주  19.0
# 12          삼성  19.0
# 13        건영2차  18.0
# 14    옥구마을건영7차  18.0
# 15        세종1차  17.0
# 16  시화평안마을건영5차  17.0
# 17        세종2차  16.0
# 18        영남4차  16.0
# 19        영남6차  15.0

# %%
#x축 한글 깨짐 처리하기
import pandas as pd
#matplotlib 패키지 한글 깨짐 처리 시작
import matplotlib.pyplot as plt
import platform
platform.system() == 'Windows'#윈도우
plt.rc('font', family='Malgun Gothic') 

plt.rcParams['axes.unicode_minus'] = False

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(17,8))
plt.xticks(rotation=45)
plt.rc('axes', labelsize=10)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=15)  # y축 눈금 폰트 크기
plt.title("아파트 관리비", fontsize=30)
plt.xlabel("아파트 이름", fontsize=15)
plt.ylabel("관리비", fontsize=15)
sns.barplot(x='아파트',y='관리비', data=result_2)
# Out:
# <AxesSubplot:title={'center':'아파트 관리비'}, xlabel='아파트', ylabel='관리비'>

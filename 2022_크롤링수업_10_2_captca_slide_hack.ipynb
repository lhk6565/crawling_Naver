# %% [markdown]
# #### Capcha 사이트 들어가서 슬라이드 캡쳐 메뉴까지 가지

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from PIL import Image
import pyautogui
from io import BytesIO
import time, os, random

pyautogui.MINIMUM_DURATION = 0
#BROWSER_MENU_HEIGHT = 170
THRESHOLD = 100

os.makedirs('snaps', exist_ok=True)

driver = webdriver.Chrome()

driver.get('https://www.geetest.com/en/demo')
driver.implicitly_wait(3)
driver.set_window_position(0, 0, windowHandle='current')

#driver.find_element(By.CSS_SELECTOR, 'div[class="tab-item tab-item-1"]').click()
#driver.find_element(By.CLASS_NAME, 'div[class="tab-item tab-item-1"]').click()
driver.find_element_by_css_selector('div[class="tab-item tab-item-1"]').click()
driver.implicitly_wait(3)

# %% [markdown]
# #### 슬라이드 캡쳐 클릭

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from PIL import Image
import pyautogui
from io import BytesIO
import time, os, random

pyautogui.MINIMUM_DURATION = 0
#BROWSER_MENU_HEIGHT = 170
THRESHOLD = 100

os.makedirs('snaps', exist_ok=True)

driver = webdriver.Chrome()

driver.get('https://www.geetest.com/en/demo')
driver.implicitly_wait(3)
driver.set_window_position(0, 0, windowHandle='current')

#driver.find_element(By.CSS_SELECTOR, 'div[class="tab-item tab-item-1"]').click()
#driver.find_element(By.CLASS_NAME, 'div[class="tab-item tab-item-1"]').click()
driver.find_element_by_css_selector('div[class="tab-item tab-item-1"]').click()
driver.implicitly_wait(3)

time.sleep(1)

radar_btn = driver.find_element(By.CSS_SELECTOR, 'div[class="geetest_radar_btn"]').click()
# Out:
# C:\Users\user\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:24: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead

# %% [markdown]
# #### 슬라이드 캡쳐 버튼에는 마우스 레이더가 존재!!!! 이걸 피하기 위해 pyautogui 이용

# %%
import pyautogui

# 좌표 객체 얻기 
position = pyautogui.position()

position
# Out:
# Point(x=892, y=490)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from PIL import Image
import pyautogui
from io import BytesIO
import time, os, random

pyautogui.MINIMUM_DURATION = 0
#BROWSER_MENU_HEIGHT = 170
THRESHOLD = 100

os.makedirs('snaps', exist_ok=True)

driver = webdriver.Chrome()

driver.get('https://www.geetest.com/en/demo')
driver.implicitly_wait(3)
driver.set_window_position(0, 0, windowHandle='current')

#driver.find_element(By.CSS_SELECTOR, 'div[class="tab-item tab-item-1"]').click()
#driver.find_element(By.CLASS_NAME, 'div[class="tab-item tab-item-1"]').click()
driver.find_element_by_css_selector('div[class="tab-item tab-item-1"]').click()
driver.implicitly_wait(3)

time.sleep(1)
pyautogui.moveTo(892,490)
pyautogui.click()
pyautogui.scroll(-300, x=892,y=490)

radar_btn = driver.find_element(By.CSS_SELECTOR, 'div[class="geetest_radar_btn"]')
#pyautogui.moveTo(radar_btn.location['x'] + 50, radar_btn.location['y']-100, duration=2)
pyautogui.moveTo(radar_btn.location['x'] + 50, radar_btn.location['y']-100, duration=2, tween=pyautogui.easeInOutElastic)
pyautogui.click(duration=0.1)
# Out:
# C:\Users\user\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead

# %% [markdown]
# #### 맨 밑으로 스크롤하기

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from PIL import Image
import pyautogui
from io import BytesIO
import time, os, random

pyautogui.MINIMUM_DURATION = 0
#BROWSER_MENU_HEIGHT = 170
THRESHOLD = 100

os.makedirs('snaps', exist_ok=True)

driver = webdriver.Chrome()

driver.get('https://www.geetest.com/en/demo')
driver.implicitly_wait(3)
driver.set_window_position(0, 0, windowHandle='current')

#driver.find_element(By.CSS_SELECTOR, 'div[class="tab-item tab-item-1"]').click()
#driver.find_element(By.CLASS_NAME, 'div[class="tab-item tab-item-1"]').click()
driver.find_element_by_css_selector('div[class="tab-item tab-item-1"]').click()
driver.implicitly_wait(3)

time.sleep(1)
pyautogui.moveTo(892,490)
pyautogui.click()
pyautogui.scroll(-300, x=892,y=490)

radar_btn = driver.find_element(By.CSS_SELECTOR, 'div[class="geetest_radar_btn"]')
#pyautogui.moveTo(radar_btn.location['x'] + 50, radar_btn.location['y']-100, duration=2)
pyautogui.moveTo(radar_btn.location['x'] + 50, radar_btn.location['y']-100, duration=2, tween=pyautogui.easeInOutElastic)
pyautogui.click(duration=0.1)

#pyautogui.moveTo(892,490)
#pyautogui.click()

for _ in range(10):
    pyautogui.scroll(-100)
time.sleep(1)
# Out:
# C:\Users\user\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead

# %% [markdown]
# ##### 스크롤을 원할하게 하기 위해 다른데 클릭해두기!

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from PIL import Image
import pyautogui
from io import BytesIO
import time, os, random

pyautogui.MINIMUM_DURATION = 0
#BROWSER_MENU_HEIGHT = 170
THRESHOLD = 100

os.makedirs('snaps', exist_ok=True)

driver = webdriver.Chrome()

driver.get('https://www.geetest.com/en/demo')
driver.implicitly_wait(3)
driver.set_window_position(0, 0, windowHandle='current')

#driver.find_element(By.CSS_SELECTOR, 'div[class="tab-item tab-item-1"]').click()
#driver.find_element(By.CLASS_NAME, 'div[class="tab-item tab-item-1"]').click()
driver.find_element_by_css_selector('div[class="tab-item tab-item-1"]').click()
driver.implicitly_wait(3)

time.sleep(1)
pyautogui.moveTo(892,490)
pyautogui.click()
pyautogui.scroll(-300, x=892,y=490)

radar_btn = driver.find_element(By.CSS_SELECTOR, 'div[class="geetest_radar_btn"]')
#pyautogui.moveTo(radar_btn.location['x'] + 50, radar_btn.location['y']-100, duration=2)
pyautogui.moveTo(radar_btn.location['x'] + 50, radar_btn.location['y']-100, duration=2, tween=pyautogui.easeInOutElastic)
pyautogui.click(duration=0.1)

pyautogui.moveTo(892,490)
pyautogui.click()

for _ in range(10):
    pyautogui.scroll(-100)
time.sleep(1)
# Out:
# C:\Users\user\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead

# %% [markdown]
# #### 이미지 캡쳐하기

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from PIL import Image
import pyautogui
from io import BytesIO
import time, os, random

pyautogui.MINIMUM_DURATION = 0
#BROWSER_MENU_HEIGHT = 170
THRESHOLD = 100

os.makedirs('snaps', exist_ok=True)

driver = webdriver.Chrome()

driver.get('https://www.geetest.com/en/demo')
driver.implicitly_wait(3)
driver.set_window_position(0, 0, windowHandle='current')

#driver.find_element(By.CSS_SELECTOR, 'div[class="tab-item tab-item-1"]').click()
#driver.find_element(By.CLASS_NAME, 'div[class="tab-item tab-item-1"]').click()
driver.find_element_by_css_selector('div[class="tab-item tab-item-1"]').click()
driver.implicitly_wait(3)

time.sleep(1)
pyautogui.moveTo(892,490)
pyautogui.click()
pyautogui.scroll(-300, x=892,y=490)

radar_btn = driver.find_element(By.CSS_SELECTOR, 'div[class="geetest_radar_btn"]')
#pyautogui.moveTo(radar_btn.location['x'] + 50, radar_btn.location['y']-100, duration=2)
pyautogui.moveTo(radar_btn.location['x'] + 50, radar_btn.location['y']-100, duration=2, tween=pyautogui.easeInOutElastic)
pyautogui.click(duration=0.1)

pyautogui.moveTo(892,490)
pyautogui.click()

for _ in range(10):
    pyautogui.scroll(-100)
time.sleep(1)

# Get images
img_el = driver.find_element(By.CSS_SELECTOR, 'canvas[class="geetest_canvas_slice geetest_absolute"]')

byte = img_el.screenshot_as_png #스크린샷 버튼!
puzzle_img = Image.open(BytesIO(byte)) #PIL Image 로 열기
#puzzle_img.show()
#puzzle_img.save(os.path.join('snaps', f'snap_{time.time()}.png'))
# Out:
# C:\Users\user\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead

# %% [markdown]
# #### 퍼즐 이미지 왜 원본 이미지 추출하기

# %% [markdown]
# driver.execute_script(
#     '''var x = document.getElementsByClassName('geetest_canvas_fullbg geetest_fade geetest_absolute')[0];
#     x.style.display = 'block';
#     x.style.opacity = 1'''
# )

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from PIL import Image
import pyautogui
from io import BytesIO
import time, os, random

pyautogui.MINIMUM_DURATION = 0
#BROWSER_MENU_HEIGHT = 170
THRESHOLD = 100

os.makedirs('snaps', exist_ok=True)

driver = webdriver.Chrome()

driver.get('https://www.geetest.com/en/demo')
driver.implicitly_wait(3)
driver.set_window_position(0, 0, windowHandle='current')

#driver.find_element(By.CSS_SELECTOR, 'div[class="tab-item tab-item-1"]').click()
#driver.find_element(By.CLASS_NAME, 'div[class="tab-item tab-item-1"]').click()
driver.find_element_by_css_selector('div[class="tab-item tab-item-1"]').click()
driver.implicitly_wait(3)

time.sleep(1)
pyautogui.moveTo(892,490)
pyautogui.click()
pyautogui.scroll(-300, x=892,y=490)

radar_btn = driver.find_element(By.CSS_SELECTOR, 'div[class="geetest_radar_btn"]')
#pyautogui.moveTo(radar_btn.location['x'] + 50, radar_btn.location['y']-100, duration=2)
pyautogui.moveTo(radar_btn.location['x'] + 50, radar_btn.location['y']-100, duration=2, tween=pyautogui.easeInOutElastic)
pyautogui.click(duration=0.1)

pyautogui.moveTo(892,490)
pyautogui.click()

for _ in range(10):
    pyautogui.scroll(-100)
time.sleep(1)

# Get images
img_el = driver.find_element(By.CSS_SELECTOR, 'canvas[class="geetest_canvas_slice geetest_absolute"]')

byte = img_el.screenshot_as_png #스크린샷 버튼!
puzzle_img = Image.open(BytesIO(byte)) #PIL Image 로 열기
puzzle_img.show()

driver.execute_script(
    '''var x = document.getElementsByClassName('geetest_canvas_fullbg geetest_fade geetest_absolute')[0];
    x.style.display = 'block';
    x.style.opacity = 1'''
)

time.sleep(0.5)
byte = img_el.screenshot_as_png
complete_img = Image.open(BytesIO(byte))
complete_img.show()
# Out:
# C:\Users\user\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead

# %% [markdown]
# #### 퍼즐 이미지 vs 원본 이미지 차이 비교하기

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from PIL import Image
import pyautogui
from io import BytesIO
import time, os, random

pyautogui.MINIMUM_DURATION = 0
#BROWSER_MENU_HEIGHT = 170
THRESHOLD = 100

os.makedirs('snaps', exist_ok=True)

driver = webdriver.Chrome()

driver.get('https://www.geetest.com/en/demo')
driver.implicitly_wait(3)
driver.set_window_position(0, 0, windowHandle='current')

#driver.find_element(By.CSS_SELECTOR, 'div[class="tab-item tab-item-1"]').click()
#driver.find_element(By.CLASS_NAME, 'div[class="tab-item tab-item-1"]').click()
driver.find_element_by_css_selector('div[class="tab-item tab-item-1"]').click()
driver.implicitly_wait(3)

time.sleep(1)
pyautogui.moveTo(892,490)
pyautogui.click()
pyautogui.scroll(-300, x=892,y=490)

radar_btn = driver.find_element(By.CSS_SELECTOR, 'div[class="geetest_radar_btn"]')
#pyautogui.moveTo(radar_btn.location['x'] + 50, radar_btn.location['y']-100, duration=2)
pyautogui.moveTo(radar_btn.location['x'] + 50, radar_btn.location['y']-100, duration=2, tween=pyautogui.easeInOutElastic)
pyautogui.click(duration=0.1)

pyautogui.moveTo(892,490)
pyautogui.click()

for _ in range(10):
    pyautogui.scroll(-100)
time.sleep(1)

# Get images
img_el = driver.find_element(By.CSS_SELECTOR, 'canvas[class="geetest_canvas_slice geetest_absolute"]')

byte = img_el.screenshot_as_png #스크린샷 버튼!
puzzle_img = Image.open(BytesIO(byte)) #PIL Image 로 열기
puzzle_img.show()

driver.execute_script(
    '''var x = document.getElementsByClassName('geetest_canvas_fullbg geetest_fade geetest_absolute')[0];
    x.style.display = 'block';
    x.style.opacity = 1'''
)

time.sleep(0.5)
byte = img_el.screenshot_as_png
complete_img = Image.open(BytesIO(byte))
complete_img.show()


def get_distance(img1, img2):
    for x in range(60, img1.size[0]):
        for y in range(img1.size[1]):
            rgb1 = img1.getpixel((x, y))
            rgb2 = img2.getpixel((x, y))

            diff_r = abs(rgb1[0] - rgb2[0])
            diff_g = abs(rgb1[1] - rgb2[1])
            diff_b = abs(rgb1[2] - rgb2[2])

            if diff_r > THRESHOLD or diff_g > THRESHOLD or diff_b > THRESHOLD:
                return x

distance = get_distance(puzzle_img, complete_img) # some calibration needed
print(distance)
# Out:
# C:\Users\user\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# 80

# %% [markdown]
# #### 함수 파헤쳐보기

# %%
THRESHOLD = 150
def get_distance(img1, img2):
    for x in range(60, img1.size[0]):
        for y in range(img1.size[1]):
            rgb1 = img1.getpixel((x, y))
            rgb2 = img2.getpixel((x, y))

            diff_r = abs(rgb1[0] - rgb2[0])
            diff_g = abs(rgb1[1] - rgb2[1])
            diff_b = abs(rgb1[2] - rgb2[2])

            if diff_r > THRESHOLD or diff_g > THRESHOLD or diff_b > THRESHOLD:
                return x

# %%
puzzle_img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=260x160 at 0x2C0A29AFE88>

# %%
complete_img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=260x160 at 0x2C0A29AFC48>

# %%
complete_img.size
# Out:
# (260, 160)

# %%
complete_img.size[0]
# Out:
# 260

# %%
new_pixel=complete_img.getpixel((61, 50))
new_pixel
# Out:
# (76, 68, 64, 255)

# %%
distance = get_distance(puzzle_img, complete_img) # some calibration needed
print(distance)
# Out:
# 76

# %% [markdown]
# #### getpixel 값은 rbg 값을 배출해 냄.
# THRESHOLD=100 이라고 가정하고
# diff_r > THRESHOLD or diff_g > THRESHOLD or diff_b > THRESHOLD 이면 퍼즐이 시작하는 구분이구나 라고 가설을 세움!

# %% [markdown]
# 이제 슬라이드 버튼을 찾기

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from PIL import Image
import pyautogui
from io import BytesIO
import time, os, random

pyautogui.MINIMUM_DURATION = 0
BROWSER_MENU_HEIGHT = 170
THRESHOLD = 150

os.makedirs('snaps', exist_ok=True)

driver = webdriver.Chrome()

driver.get('https://www.geetest.com/en/demo')
driver.implicitly_wait(3)
driver.set_window_position(0, 0, windowHandle='current')

#driver.find_element(By.CSS_SELECTOR, 'div[class="tab-item tab-item-1"]').click()
#driver.find_element(By.CLASS_NAME, 'div[class="tab-item tab-item-1"]').click()
driver.find_element_by_css_selector('div[class="tab-item tab-item-1"]').click()
driver.implicitly_wait(3)

time.sleep(1)
pyautogui.moveTo(892,490)
pyautogui.click()
pyautogui.scroll(-300, x=892,y=490)

radar_btn = driver.find_element(By.CSS_SELECTOR, 'div[class="geetest_radar_btn"]')
#pyautogui.moveTo(radar_btn.location['x'] + 50, radar_btn.location['y']-100, duration=2)
pyautogui.moveTo(radar_btn.location['x'] + 50, radar_btn.location['y']-100, duration=2, tween=pyautogui.easeInOutElastic)
pyautogui.click(duration=0.1)

pyautogui.moveTo(892,490)
pyautogui.click()

for _ in range(10):
    pyautogui.scroll(-100)
time.sleep(1)

# Get images
img_el = driver.find_element(By.CSS_SELECTOR, 'canvas[class="geetest_canvas_slice geetest_absolute"]')

byte = img_el.screenshot_as_png #스크린샷 버튼!
puzzle_img = Image.open(BytesIO(byte)) #PIL Image 로 열기
#puzzle_img.show()

driver.execute_script(
    '''var x = document.getElementsByClassName('geetest_canvas_fullbg geetest_fade geetest_absolute')[0];
    x.style.display = 'block';
    x.style.opacity = 1'''
)

time.sleep(0.5)
byte = img_el.screenshot_as_png
complete_img = Image.open(BytesIO(byte))
#complete_img.show()


def get_distance(img1, img2):
    for x in range(60, img1.size[0]):
        for y in range(img1.size[1]):
            rgb1 = img1.getpixel((x, y))
            rgb2 = img2.getpixel((x, y))

            diff_r = abs(rgb1[0] - rgb2[0])
            diff_g = abs(rgb1[1] - rgb2[1])
            diff_b = abs(rgb1[2] - rgb2[2])

            if diff_r > THRESHOLD or diff_g > THRESHOLD or diff_b > THRESHOLD:
                return x

distance = get_distance(puzzle_img, complete_img) # some calibration needed
print(distance)

# Move slide button
slider_button = driver.find_element(By.CSS_SELECTOR, 'div[class="geetest_slider_button"]')

pyautogui.moveTo(slider_button.location['x'] + 40, slider_button.location['y']  + BROWSER_MENU_HEIGHT, duration=0.2, tween=pyautogui.easeInOutElastic)
#pyautogui.mouseDown()

# %% [markdown]
# ##### 하지만 이러면 마우스가 사라진다??!!
#
# 스크롤이 되서 처음 (0,0) 위치가 달라서 다시 찾아줘야함!

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from PIL import Image
import pyautogui
from io import BytesIO
import time, os, random

pyautogui.MINIMUM_DURATION = 0
BROWSER_MENU_HEIGHT = 170
THRESHOLD = 150

os.makedirs('snaps', exist_ok=True)

driver = webdriver.Chrome()

driver.get('https://www.geetest.com/en/demo')
driver.implicitly_wait(3)
driver.set_window_position(0, 0, windowHandle='current')

#driver.find_element(By.CSS_SELECTOR, 'div[class="tab-item tab-item-1"]').click()
#driver.find_element(By.CLASS_NAME, 'div[class="tab-item tab-item-1"]').click()
driver.find_element_by_css_selector('div[class="tab-item tab-item-1"]').click()
driver.implicitly_wait(3)

time.sleep(1)
pyautogui.moveTo(892,490)
pyautogui.click()
pyautogui.scroll(-300, x=892,y=490)

radar_btn = driver.find_element(By.CSS_SELECTOR, 'div[class="geetest_radar_btn"]')
#pyautogui.moveTo(radar_btn.location['x'] + 50, radar_btn.location['y']-100, duration=2)
pyautogui.moveTo(radar_btn.location['x'] + 50, radar_btn.location['y']-100, duration=2, tween=pyautogui.easeInOutElastic)
pyautogui.click(duration=0.1)

pyautogui.moveTo(892,490)
pyautogui.click()

for _ in range(10):
    pyautogui.scroll(-100)
time.sleep(1)

# Get images
img_el = driver.find_element(By.CSS_SELECTOR, 'canvas[class="geetest_canvas_slice geetest_absolute"]')

byte = img_el.screenshot_as_png #스크린샷 버튼!
puzzle_img = Image.open(BytesIO(byte)) #PIL Image 로 열기
#puzzle_img.show()

driver.execute_script(
    '''var x = document.getElementsByClassName('geetest_canvas_fullbg geetest_fade geetest_absolute')[0];
    x.style.display = 'block';
    x.style.opacity = 1'''
)

time.sleep(0.5)
byte = img_el.screenshot_as_png
complete_img = Image.open(BytesIO(byte))
#complete_img.show()


def get_distance(img1, img2):
    for x in range(60, img1.size[0]):
        for y in range(img1.size[1]):
            rgb1 = img1.getpixel((x, y))
            rgb2 = img2.getpixel((x, y))

            diff_r = abs(rgb1[0] - rgb2[0])
            diff_g = abs(rgb1[1] - rgb2[1])
            diff_b = abs(rgb1[2] - rgb2[2])

            if diff_r > THRESHOLD or diff_g > THRESHOLD or diff_b > THRESHOLD:
                return x

distance = get_distance(puzzle_img, complete_img) - 7 # some calibration needed
print(distance)

# Move slide button
slider_button = driver.find_element(By.CSS_SELECTOR, 'div[class="geetest_slider_button"]')
scroll = driver.execute_script('return window.scrollY;') # get scroll positon 스크롤한 양을 js 함수에서 구한다
print(scroll)

pyautogui.moveTo(slider_button.location['x'] + 40, slider_button.location['y'] - scroll + BROWSER_MENU_HEIGHT, duration=0.2, tween=pyautogui.easeInOutElastic)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39828\2681201100.py in <module>
#      17 driver.get('https://www.geetest.com/en/demo')
#      18 driver.implicitly_wait(3)
# ---> 19 driver.set_window_position(0, 0, windowHandle='current')
#      20
#      21 #driver.find_element(By.CSS_SELECTOR, 'div[class="tab-item tab-item-1"]').click()
#
# ~\anaconda3\envs\selenium\lib\site-packages\selenium\webdriver\remote\webdriver.py in set_window_position(self, x, y, windowHandle)
#    1416         if windowHandle != 'current':
#    1417             warnings.warn("Only 'current' window is supported for W3C compatible browsers.")
# -> 1418         return self.set_window_rect(x=int(x), y=int(y))
#    1419
#    1420     def get_window_position(self, windowHandle='current') -> dict:
#
# ~\anaconda3\envs\selenium\lib\site-packages\selenium\webdriver\remote\webdriver.py in set_window_rect(self, x, y, width, height)
#    1466         return self.execute(Command.SET_WINDOW_RECT, {"x": x, "y": y,
#    1467                                                       "width": width,
# -> 1468                                                       "height": height})['value']
#    1469
#    1470     @property
#
# ~\anaconda3\envs\selenium\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# ~\anaconda3\envs\selenium\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=97.0.4692.71)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x009B6903+2517251]
# 	Ordinal0 [0x0094F8E1+2095329]
# 	Ordinal0 [0x00852848+1058888]
# 	Ordinal0 [0x0083BF90+966544]
# 	Ordinal0 [0x00898999+1345945]
# 	Ordinal0 [0x008A5342+1397570]
# 	Ordinal0 [0x0089639B+1336219]
# 	Ordinal0 [0x008727A7+1189799]
# 	Ordinal0 [0x00873609+1193481]
# 	GetHandleVerifier [0x00B45904+1577972]
# 	GetHandleVerifier [0x00BF0B97+2279047]
# 	GetHandleVerifier [0x00A46D09+534521]
# 	GetHandleVerifier [0x00A45DB9+530601]
# 	Ordinal0 [0x00954FF9+2117625]
# 	Ordinal0 [0x009598A8+2136232]
# 	Ordinal0 [0x009599E2+2136546]
# 	Ordinal0 [0x00963541+2176321]
# 	BaseThreadInitThunk [0x773CFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77C57A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77C57A6E+238]

# %% [markdown]
# #### 마우스 드레그 하기!

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from PIL import Image
import pyautogui
from io import BytesIO
import time, os, random

pyautogui.MINIMUM_DURATION = 0
BROWSER_MENU_HEIGHT = 170
THRESHOLD = 150

os.makedirs('snaps', exist_ok=True)

driver = webdriver.Chrome()

driver.get('https://www.geetest.com/en/demo')
driver.implicitly_wait(3)
driver.set_window_position(0, 0, windowHandle='current')

#driver.find_element(By.CSS_SELECTOR, 'div[class="tab-item tab-item-1"]').click()
#driver.find_element(By.CLASS_NAME, 'div[class="tab-item tab-item-1"]').click()
driver.find_element_by_css_selector('div[class="tab-item tab-item-1"]').click()
driver.implicitly_wait(3)

time.sleep(1)
pyautogui.moveTo(892,490)
pyautogui.click()
pyautogui.scroll(-300, x=892,y=490)

radar_btn = driver.find_element(By.CSS_SELECTOR, 'div[class="geetest_radar_btn"]')
#pyautogui.moveTo(radar_btn.location['x'] + 50, radar_btn.location['y']-100, duration=2)
pyautogui.moveTo(radar_btn.location['x'] + 50, radar_btn.location['y']-100, duration=2, tween=pyautogui.easeInOutElastic)
pyautogui.click(duration=0.1)

pyautogui.moveTo(892,490)
pyautogui.click()

for _ in range(10):
    pyautogui.scroll(-100)
time.sleep(1)

# Get images
img_el = driver.find_element(By.CSS_SELECTOR, 'canvas[class="geetest_canvas_slice geetest_absolute"]')

byte = img_el.screenshot_as_png #스크린샷 버튼!
puzzle_img = Image.open(BytesIO(byte)) #PIL Image 로 열기
#puzzle_img.show()

driver.execute_script(
    '''var x = document.getElementsByClassName('geetest_canvas_fullbg geetest_fade geetest_absolute')[0];
    x.style.display = 'block';
    x.style.opacity = 1'''
)

time.sleep(0.5)
byte = img_el.screenshot_as_png
complete_img = Image.open(BytesIO(byte))
#complete_img.show()


def get_distance(img1, img2):
    for x in range(80, img1.size[0]):
        for y in range(img1.size[1]):
            rgb1 = img1.getpixel((x, y))
            rgb2 = img2.getpixel((x, y))

            diff_r = abs(rgb1[0] - rgb2[0])
            diff_g = abs(rgb1[1] - rgb2[1])
            diff_b = abs(rgb1[2] - rgb2[2])

            if diff_r > THRESHOLD or diff_g > THRESHOLD or diff_b > THRESHOLD:
                return x

distance = get_distance(puzzle_img, complete_img) - 7 # some calibration needed
print(distance)

# Move slide button
slider_button = driver.find_element(By.CSS_SELECTOR, 'div[class="geetest_slider_button"]')
scroll = driver.execute_script('return window.scrollY;') # get scroll positon 스크롤한 양을 js 함수에서 구한다
print(scroll)

pyautogui.moveTo(slider_button.location['x'] + 40, slider_button.location['y'] - scroll + BROWSER_MENU_HEIGHT, duration=0.2, tween=pyautogui.easeInOutElastic)
pyautogui.mouseDown()

new_dis=distance

pyautogui.moveRel(new_dis, 0, duration=2)
pyautogui.mouseUp()
# Out:
# C:\Users\user\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# 149
# 548

# %% [markdown]
# #### 사람같이 마우스 움직이게 하기 dx dy dt 이용

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from PIL import Image
import pyautogui
from io import BytesIO
import time, os, random

pyautogui.MINIMUM_DURATION = 0
BROWSER_MENU_HEIGHT = 170
THRESHOLD = 150

os.makedirs('snaps', exist_ok=True)

driver = webdriver.Chrome()

driver.get('https://www.geetest.com/en/demo')
driver.implicitly_wait(3)
driver.set_window_position(0, 0, windowHandle='current')

#driver.find_element(By.CSS_SELECTOR, 'div[class="tab-item tab-item-1"]').click()
#driver.find_element(By.CLASS_NAME, 'div[class="tab-item tab-item-1"]').click()
driver.find_element_by_css_selector('div[class="tab-item tab-item-1"]').click()
driver.implicitly_wait(3)

time.sleep(1)
pyautogui.moveTo(892,490)
pyautogui.click()
pyautogui.scroll(-300, x=892,y=490)

radar_btn = driver.find_element(By.CSS_SELECTOR, 'div[class="geetest_radar_btn"]')
#pyautogui.moveTo(radar_btn.location['x'] + 50, radar_btn.location['y']-100, duration=2)
pyautogui.moveTo(radar_btn.location['x'] + 50, radar_btn.location['y']-100, duration=2, tween=pyautogui.easeInOutElastic)
pyautogui.click(duration=0.1)

pyautogui.moveTo(892,490)
pyautogui.click()

for _ in range(10):
    pyautogui.scroll(-100)
time.sleep(1)

# Get images
img_el = driver.find_element(By.CSS_SELECTOR, 'canvas[class="geetest_canvas_slice geetest_absolute"]')

byte = img_el.screenshot_as_png #스크린샷 버튼!
puzzle_img = Image.open(BytesIO(byte)) #PIL Image 로 열기
#puzzle_img.show()
puzzle_img.save(os.path.join('snaps', f'snap_{time.time()}.png'))

driver.execute_script(
    '''var x = document.getElementsByClassName('geetest_canvas_fullbg geetest_fade geetest_absolute')[0];
    x.style.display = 'block';
    x.style.opacity = 1'''
)

time.sleep(0.5)
byte = img_el.screenshot_as_png
complete_img = Image.open(BytesIO(byte))
#complete_img.show()
complete_img.save(os.path.join('snaps', f'snap_{time.time()}.png'))

def get_distance(img1, img2):
    for x in range(100, img1.size[0]):
        for y in range(img1.size[1]):
            rgb1 = img1.getpixel((x, y))
            rgb2 = img2.getpixel((x, y))

            diff_r = abs(rgb1[0] - rgb2[0])
            diff_g = abs(rgb1[1] - rgb2[1])
            diff_b = abs(rgb1[2] - rgb2[2])

            if diff_r > THRESHOLD or diff_g > THRESHOLD or diff_b > THRESHOLD:
                return x

distance = get_distance(puzzle_img, complete_img) - 7 # some calibration needed
print(distance)

# Move slide button
slider_button = driver.find_element(By.CSS_SELECTOR, 'div[class="geetest_slider_button"]')
scroll = driver.execute_script('return window.scrollY;') # get scroll positon 스크롤한 양을 js 함수에서 구한다
print(scroll)

pyautogui.moveTo(slider_button.location['x'] + 40, slider_button.location['y'] - scroll + BROWSER_MENU_HEIGHT, duration=0.2, tween=pyautogui.easeInOutElastic)
pyautogui.mouseDown()

current_x = 0

while True:
    dx = random.randint(50, 100)
    dy = random.randint(-8, 8)
    print(dx, dy)
    pyautogui.moveRel(xOffset=dx, yOffset=dy, duration=random.randint(50, 100) / 100, tween=pyautogui.easeInOutSine)

    current_x += dx

    if current_x >= distance:
        dx = distance - current_x
        dy = random.randint(-8, 8)
        print(dx, dy)
        pyautogui.moveRel(xOffset=dx, yOffset=dy, duration=0.25, tween=pyautogui.easeInOutSine)
        break
# Out:
# C:\Users\user\anaconda3\envs\selenium\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# 144
# 548
# 75 -6
# 89 -3
# -20 -4
